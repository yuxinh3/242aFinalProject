# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %ls
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# drive/  gdrive/  sample_data/

# %%
# %cd MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# %ls
# Out:
#  270B/                                                     'LLM Project'/
#  270C/                                                      MA_pyhon_test.ipynb
#  270L/                                                      modeling_dataset.csv
# '295_Report_team 87_Vivian.docx'                           'New school'/
# 'Capstone Project Selection.gsheet'                         NTHU/
#  Capstone_Vivian/                                           Resume_ChiangWei_Capstone.pdf
#  Career/                                                    Resume_Vivian_Capstone.pdf
#  CCI.gsheet                                                 Resume_Vivian_data_0118.pdf
# 'Colab Notebooks'/                                          Resume_Vivian_data.pdf
# 'Copy of Capstone 2023 - Meeting #9 (01 30 2024).gslides'  'Untitled document.gdoc'
# 'Copy of E270K Module 1.gslides'                           'Untitled spreadsheet (1).gsheet'
# 'E270K Module 4.gslides'                                   'Untitled spreadsheet.gsheet'
#  important/                                                 Vivian_open.xlsx
# 'INDENG 230'/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
from functools import reduce
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
